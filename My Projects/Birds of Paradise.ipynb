# %%
#Step 1: Rare Birds Dictionary
rarebirds = {
    'Gold-crested Toucan': {
        'Height (m)': 1.1,
        'Weight (kg)': 35,
        'Color': 'Gold',
        'Endangered': True,
        'Aggressive': True
},
'Pearlescent Kingfisher': {
        'Height (m)': 0.25,
        'Weight (kg)': 0.5,
        'Color': 'White',
        'Endangered': True,
        'Aggressive': True
},
'Four-metre Hummingbird': {
        'Height (m)': 0.6,
        'Weight (kg)': 0.5,
        'Color': 'Blue',
        'Endangered': True,
        'Aggressive': True
},
'Giant Eagle': {
        'Height (m)': 1.5,
        'Weight (kg)': 52,
        'Color': 'Black and White',
        'Endangered': True,
        'Aggressive': True
},
'Ancient Vulture': {
        'Height (m)': 2.1,
        'Weight (kg)': 70,
        'Color': 'Brown',
        'Endangered': True,
        'Aggressive': True
}
}

#Step 2: Rare Bird Locations
bird_location = [
'In the canopy directly above our heads.',
'Between my 6 and 9 o’clock above.',
'Between my 9 and 12 o’clock above.',
'Between my 12 and 3 o’clock above.',
'Between my 3 and 6 o’clock above.',
'In a nest on the ground.',
'Right behind you.'
]

#Step 3: Codes for Locations
codes = {
'001: In the canopy directly above our heads.',
'010: Between my 6 and 9 o’clock above.',
'011: Between my 9 and 12 o’clock above.',
'100: Between my 12 and 3 o’clock above.',
'101: Between my 3 and 6 o’clock above.',
'110: In a nest on the ground.',
'111: Right behind you.'}

#Step 4: Actions
actions = ['Back Away', 'Cover our Heads', 'Take a Photograph']

#Step 5: Print whether or not giant eagle is aggressive
print(rarebirds['Giant Eagle']['Aggressive'])

#Step 6: What to do when bird found
for key, value in rarebirds.items():
    print('How to handle birds: ')
    if value['Aggressive'] == True && value['Endangered'] == True:
        print(key + ' ' + actions[1] + ' ' + actions[0])

#Step 7: Print values of codes dictionary
print('Bird Locations: ')
for key, value in codes.items():
    print(key + ' ' + value)

#Step 8: Add 'seen' attribute
for value in rarebirds.values():
    value['Seen'] == False

#Step 9: Add 'encounter' variable set to True
encounter = True

#Step 10: Sighting input:
sighting = input('What do you see? ')

#Step 11: List of birds
rarebirdslist = [rarebirds.keys()]

#Step 12: Is sighting a rare bird?
if sighting in rarebirdslist:
    print('This is one of the birds we are looking for!')
else:
    print('That\'s not one of the birds we\'re looking for.')

#Step 13: Input bird location
code = input('Where do you see it? ')

#Step 14: New location variable
location = [rarebirds.value('Location')]

#Step 15: Print bird sighting
print('So you\'ve seen a', sighting)

#Step 16: Is bird aggressive or endangered?
if sighting == 'Aggressive':
    print(key + ' is aggressive' + actions[0])
elif sighting == 'Endangered':
    print(key + ' is endangered' + actions[0])
else:
    print('We need to photograph the ultra rare ' + sighting + ' at its location ' + location)

#Step 17: Modify steps 9-16 into a while loop and encounter == False in if, elif, or else statements
while encounter = True:

    sighting = input('What do you see? ')

    rarebirdslist = [rarebirds.keys()]

    if sighting in rarebirdslist:
        print('This is one of the birds we are looking for!')
    else:
        print('That\'s not one of the birds we\'re looking for.')

    code = input('Where do you see it? ')

    location = [rarebirds.value('Location')]

    print('So you\'ve seen a', sighting)

    if sighting == 'Aggressive':
        print(key + ' is aggressive' + actions[0])
        encounter == False
    elif sighting == 'Endangered':
        print(key + ' is endangered' + actions[0])
        encounter == False
    else:
        print('We need to photograph the ultra rare ' + sighting + ' at its location ' + location)
